# %%
var('x')
P1=plot(exp(x)/(1+x),0,1)
P2=plot(sqrt(x/(2-x^2)),0,1)
P1+P2
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot( exp_polar(x), x, -2, 2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('y')
assume(y>0)
assume(y<1)
solve(y == sqrt(x/(2-x^2)),x )
# Out:
# [x == -1/2*(sqrt(8*y^4 + 1) + 1)/y^2, x == 1/2*(sqrt(8*y^4 + 1) - 1)/y^2]

# %%
var('z')
z=20
function('F')
F(x) = ((1/2)*(sqrt(z*x^4 + 1) - 1)/x^2)/(1/2*(sqrt(z*1^4 + 1) - 1)/1^2)
function('f')
f= F.derivative()
plot(f(x), (0,1))
# Out:
# Graphics object consisting of 1 graphics primitive
