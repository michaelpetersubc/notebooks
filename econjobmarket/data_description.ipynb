# %%
import pandas as pd 
import os
import IPython

import json
with open("repec_rankings.json", "r") as read_file:
    rankings = json.load(read_file)
    
rankings
# Out:
# [{'ranking_sources_id': 1,
#   'name': 'University of Michigan - Department of Economics',
#   'ejm_organization_id': 186,
#   'ejm_institution_id': 2,
#   'rank': 14},
#  {'ranking_sources_id': 1,
#   'name': 'University of California Los Angeles (UCLA) - Economics',
#   'ejm_organization_id': 36,
#   'ejm_institution_id': 6,
#   'rank': 20},
#  {'ranking_sources_id': 1,
#   'name': 'University of Maryland - Economics',
#   'ejm_organization_id': 20,
#   'ejm_institution_id': 13,
#   'rank': 24},
#  {'ranking_sources_id': 1,
#   'name': 'Duke University - Economics',
#   'ejm_organization_id': 24,
#   'ejm_institution_id': 17,
#   'rank': 15},
#  {'ranking_sources_id': 1,
#   'name': 'Northwestern University - Economics',
#   'ejm_organization_id': 25,
#   'ejm_institution_id': 18,
#   'rank': 12},
#  {'ranking_sources_id': 1,
#   'name': 'Brown University - Economics',
#   'ejm_organization_id': 28,
#   'ejm_institution_id': 21,
#   'rank': 66},
#  {'ranking_sources_id': 1,
# ...
