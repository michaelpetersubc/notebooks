# %%
import pandas as pd 
import os
import IPython
ds_daa = pd.read_csv("daa_results.csv")
ds_daa.sort_values(by ='sIndex')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Unnamed: 0.1</th>
#       <th>First Name</th>
#       <th>CHOICE</th>
#       <th>ProgramName</th>
#       <th>sIndex</th>
#       <th>open</th>
#       <th>matched</th>
#       <th>augmented</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2115</th>
#       <td>0</td>
#       <td>1894</td>
#       <td>Grayson</td>
#       <td>1</td>
#       <td>Montessorri Alternate Program - Renfrew</td>
#       <td>277479538</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.668610</td>
#     </tr>
#     <tr>
#       <th>2112</th>
#       <td>1</td>
#       <td>1505</td>
# ...

# %%
ds_vsb = pd.read_csv("vsb_results.csv")
ds_vsb.sort_values(by ='sIndex')
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Unnamed: 0</th>
#       <th>Unnamed: 0.1</th>
#       <th>First Name</th>
#       <th>CHOICE</th>
#       <th>ProgramName</th>
#       <th>sIndex</th>
#       <th>open</th>
#       <th>matched</th>
#       <th>augmented</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>811</th>
#       <td>0</td>
#       <td>1894</td>
#       <td>Grayson</td>
#       <td>1</td>
#       <td>Montessorri Alternate Program - Renfrew</td>
#       <td>277479538</td>
#       <td>True</td>
#       <td>True</td>
#       <td>1.668610</td>
#     </tr>
#     <tr>
#       <th>1779</th>
#       <td>2</td>
#       <td>669</td>
# ...
